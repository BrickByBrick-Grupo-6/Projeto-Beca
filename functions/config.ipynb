# %%
from pyspark.sql.types import StructType, StructField, StringType, TimestampType

# %%
 # Encoding padrão dos arquivos
ENCODING = "ISO-8859-1"
SEP = ";"
 
# ==============================
# Schemas
# ==============================
 
#Cnaes
schema_cnaes = StructType([
    StructField("codigo_cnae", StringType(), True),
    StructField("descricao_cnae", StringType(), True),
    StructField("dt_ingestao", TimestampType(), True)
])
 
#Municipios
schema_municipios = StructType([
    StructField("codigo_municipio", StringType(), True),
    StructField("descricao_municipio", StringType(), True),
    StructField("dt_ingestao", TimestampType(), True)

])
 
#Empresas
schema_empresas = StructType([
    StructField("cnpj_basico",StringType(), True),
    StructField("razao_social",StringType(), True),
    StructField("natureza_juridica",StringType(), True),
    StructField("qualificacao_responsavel",StringType(), True),
    StructField("capital_social",StringType(), True),
    StructField("porte_empresa",StringType(), True),
    StructField("ente_federativo_responsavel",StringType(), True),
    StructField("dt_ingestao", TimestampType(), True)

])
 
#Estabelecimento
schema_estabelecimento = StructType([
    StructField("cnpj_basico",StringType(), True),
    StructField("cnpj_ordem",StringType(), True),
    StructField("cnpj_dv",StringType(), True),
    StructField("identificador_matriz_filial",StringType(), True),
    StructField("nome_fantasia",StringType(), True),
    StructField("situacao_cadastral",StringType(), True),
    StructField("data_situacao_cadastral",StringType(), True),
    StructField("motivo_situacao_cadastral",StringType(), True),
    StructField("nome_cidade_exterior",StringType(), True),
    StructField("pais",StringType(), True),
    StructField("data_inicio_atividade",StringType(), True),
    StructField("cnae_fiscal_principal",StringType(), True),
    StructField("cnae_fiscal_secundaria",StringType(), True),
    StructField("tipo_logradouro",StringType(), True),
    StructField("logradouro",StringType(), True),
    StructField("numero",StringType(), True),
    StructField("complemento",StringType(), True),
    StructField("bairro",StringType(), True),
    StructField("cep",StringType(), True),
    StructField("uf",StringType(), True),
    StructField("municipio",StringType(), True),
    StructField("ddd_1",StringType(), True),
    StructField("telefone_1",StringType(), True),
    StructField("ddd_2",StringType(), True),
    StructField("telefone_2",StringType(), True),
    StructField("ddd_fax",StringType(), True),
    StructField("numero_fax", StringType(), True),
    StructField("correio_eletronico",StringType(), True),
    StructField("situacao_especial",StringType(), True),
    StructField("data_situacao_especial",StringType(), True),
    StructField("dt_ingestao", TimestampType(), True)
])
 
#Dados Simples
schema_dados_simples = StructType([
    StructField("cnpj_basico",StringType(), True),
    StructField("opcao_simples",StringType(), True),
    StructField("data_opcao_simples",StringType(), True),
    StructField("data_exclusao_simples",StringType(), True),
    StructField("opcao_mei",StringType(), True),
    StructField("data_opcao_mei",StringType(), True),
    StructField("data_exclusao_mei",StringType(), True),
    StructField("dt_ingestao", TimestampType(), True)
])
 
#Socios
schema_socios = StructType([
    StructField("cnpj_basico",StringType(), True),
    StructField("identificador_socio",StringType(), True),
    StructField("nome_socio",StringType(), True),
    StructField("documento_cpf_cnpj",StringType(), True),
    StructField("qualificacao_socio",StringType(), True),
    StructField("data_entrada_sociedade",StringType(), True),
    StructField("pais",StringType(), True),
    StructField("cpf_representante_legal",StringType(), True),
    StructField("nome_representante",StringType(), True),
    StructField("qualificacao_representante_legal",StringType(), True),
    StructField("faixa_etaria",StringType(), True),
    StructField("dt_ingestao", TimestampType(), True)
])
 
#Pases
schema_paises = StructType([
    StructField("codigo_pais", StringType(), True),
    StructField("descricao_pais", StringType(), True),
    StructField("dt_ingestao", TimestampType(), True)
])
 
 
#Qualificacoes de socio
schema_qualificacao_socio = StructType([
    StructField("codigo_qualificacao", StringType(), True),
    StructField("descricao_qualificacao", StringType(), True),
    StructField("dt_ingestao", TimestampType(), True)
])
 
#Natureza Juridica
schema_natureza_juridica = StructType([
    StructField("codigo_natureza_juridica", StringType(), True),
    StructField("descricao_natureza_juridica", StringType(), True),
    StructField("dt_ingestao", TimestampType(), True)
])
 
#Motivos
schema_motivos = StructType([
    StructField("codigo_motivo", StringType(), True),
    StructField("descricao_motivo", StringType(), True),
    StructField("dt_ingestao", TimestampType(), True)
])
 
 
# ==============================
# Datasets
# ==============================
 
datasets = {
    "cnaes": {
        "prefixo_arquivo": "Cnaes",
        "schema": schema_cnaes
    },
    "municipios": {
        "prefixo_arquivo": "Municipios",
        "schema": schema_municipios
    },
    "empresas":{
        "prefixo_arquivo": "Empresas",
        "schema": schema_empresas
    },
    "estabelecimento":{
        "prefixo_arquivo": "Estabelecimentos",
        "schema": schema_estabelecimento
    },
    "dados_simples":{
        "prefixo_arquivo": "Simples",
        "schema": schema_dados_simples
    },
    "socios":{
        "prefixo_arquivo": "Socios",
        "schema": schema_socios
    },
     "paises": {
        "prefixo_arquivo": "Paises",
        "schema": schema_paises
    },
     "qualificacao_socio": {
        "prefixo_arquivo": "Qualificacoes",
        "schema": schema_qualificacao_socio
    },
    "natureza_juridica":{
        "prefixo_arquivo": "Naturezas",
        "schema": schema_natureza_juridica
    },
    "motivos":{
        "prefixo_arquivo": "Motivos",
        "schema": schema_motivos
    }
}
